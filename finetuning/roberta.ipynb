# %%
import numpy as np
import pandas as pd
import os
import ray
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, default_data_collator
from datasets import load_dataset, load_metric
import evaluate
import ray.data
from ray.data.preprocessors import BatchMapper
from ray.train.huggingface import HuggingFaceTrainer
from ray.air.config import RunConfig, ScalingConfig, CheckpointConfig
from ray.air.integrations.mlflow import MLflowLoggerCallback
from ray.air.integrations.wandb import WandbLoggerCallback
import wandb

# %%
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ········
# wandb: Appending key for api.wandb.ai to your netrc file: /home/rj2665/.netrc
# True

# %%
os.environ['RAY_memory_usage_threshold'] = "0.98"

# %%
model_name = "distilroberta-base"
use_gpu = True
num_workers = 2
cpus_per_worker = 1

# %%
ray.init(
    runtime_env={
        "pip": [
            "datasets",
            "evaluate",
            "accelerate>=0.16.0",
            "transformers>=4.26.0",
            "torch>=1.12.0",
            "deepspeed",
        ]
    }
)
# Out:
# 2023-05-09 01:44:40,148	INFO worker.py:1550 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.7.12', ray_version='2.3.1', ray_commit='5f14cee8dfc6d61ec4fd3bc2c440f9944e92b33a', address_info={'node_ip_address': '10.158.0.3', 'raylet_ip_address': '10.158.0.3', 'redis_address': None, 'object_store_address': '/var/tmp/ray/session_2023-05-09_01-44-38_203371_11181/sockets/plasma_store', 'raylet_socket_name': '/var/tmp/ray/session_2023-05-09_01-44-38_203371_11181/sockets/raylet', 'webui_url': '127.0.0.1:8265', 'session_dir': '/var/tmp/ray/session_2023-05-09_01-44-38_203371_11181', 'metrics_export_port': 54526, 'gcs_address': '10.158.0.3:60305', 'address': '10.158.0.3:60305', 'dashboard_agent_listen_port': 52365, 'node_id': '18cf7a29bde4465a1b9d6787898aaddd0c7468b8404b12ea592cc20b'})

# %%
imdb_data = load_dataset("imdb")
# Out:
# Found cached dataset imdb (/home/rj2665/.cache/huggingface/datasets/imdb/plain_text/1.0.0/d613c88cf8fa3bab83b4ded3713f1f74830d1100e171db75bbddb80b3345c9c0)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
ray_imdb_data = ray.data.from_huggingface(imdb_data)

# %%
ray_imdb_data
# Out:
# {'train': Dataset(num_blocks=1, num_rows=25000, schema={text: string, label: int64}),
#  'test': Dataset(num_blocks=1, num_rows=25000, schema={text: string, label: int64}),
#  'unsupervised': Dataset(num_blocks=1, num_rows=50000, schema={text: string, label: int64})}

# %%
def tokenize(batch: pd.DataFrame):
    # Tokenize the input text
    tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=False)
    tokenized_texts = tokenizer(list(batch['text']), padding=True, truncation=True, return_tensors="np")
    tokenized_texts['input_ids'] = tokenized_texts['input_ids'].tolist()
    tokenized_texts['attention_mask'] = tokenized_texts['attention_mask'].tolist()
    tokenized_texts = {**batch, **tokenized_texts}
    return pd.DataFrame.from_dict(tokenized_texts)

# %%
tokenizer = BatchMapper(tokenize, batch_format="pandas")

# %%
batch_size = 16
def trainer_init_per_worker(train_dataset, eval_dataset = None, **config):
    print(f"Is CUDA available: {torch.cuda.is_available()}")
    tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
    model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)

    torch.backends.cuda.matmul.allow_tf32 = True
    deepspeed = {
        "fp16": {
            "enabled": "auto",
            "initial_scale_power": 8,
        },
        "bf16": {"enabled": "auto"},
        "optimizer": {
            "type": "AdamW",
            "params": {
                "lr": "auto",
                "betas": "auto",
                "eps": "auto",
            },
        },
        "zero_optimization": {
            "stage": 3,
            "offload_optimizer": {
                "device": "cpu",
                "pin_memory": True,
            },
            "offload_param": {
                "device": "cpu",
                "pin_memory": True,
            },
            "overlap_comm": True,
            "contiguous_gradients": True,
            "reduce_bucket_size": "auto",
            "stage3_prefetch_bucket_size": "auto",
            "stage3_param_persistence_threshold": "auto",
            "gather_16bit_weights_on_model_save": True,
            "round_robin_gradients": True,
        },
        "gradient_accumulation_steps": "auto",
        "gradient_clipping": "auto",
        "steps_per_print": 10,
        "train_batch_size": "auto",
        "train_micro_batch_size_per_gpu": "auto",
        "wall_clock_breakdown": False,
    }
    args = TrainingArguments(
        "ray-bert-finetune-imdb",
        save_strategy="no",
        logging_steps=1,
        learning_rate=config.get("learning_rate", 2e-5),
        per_device_train_batch_size=batch_size,
        per_device_eval_batch_size=batch_size,
        label_names=["input_ids", "attention_mask"],
        num_train_epochs=config.get("epochs", 2),
        weight_decay=config.get("weight_decay", 0.01),
        fp16=True,
        # gradient_checkpointing=True,
        deepspeed=deepspeed,
        push_to_hub=False,
        disable_tqdm=True,  # declutter the output a little
        # no_cuda=not use_gpu,  # you need to explicitly set no_cuda if you want CPUs
    )

    def compute_metrics(eval_pred):
        load_accuracy = load_metric("accuracy")
        load_f1 = load_metric("f1")
        logits, labels = eval_pred
        predictions = np.argmax(logits, axis=-1)
        accuracy = load_accuracy.compute(predictions=predictions, references=labels)["accuracy"]
        f1 = load_f1.compute(predictions=predictions, references=labels)["f1"]
        return {"accuracy": accuracy, "f1": f1}


    trainer = Trainer(
        model,
        args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        tokenizer=tokenizer,
        compute_metrics=compute_metrics,
        data_collator = default_data_collator,
    )

    print("Starting training")
    return trainer

# %%
trainer = HuggingFaceTrainer(
    trainer_init_per_worker=trainer_init_per_worker,
    scaling_config=ScalingConfig(num_workers=num_workers, use_gpu=use_gpu, resources_per_worker={"GPU": 1, "CPU": 1}),
    datasets={
        "train": ray_imdb_data["train"],
        "evaluation": ray_imdb_data["test"],
    },
    run_config=RunConfig(
#         callbacks=[MLflowLoggerCallback(experiment_name="ray-roberta-finetune-imdb")],
        callbacks=[WandbLoggerCallback(project="ray-roberta-finetune-imdb")],
        checkpoint_config=CheckpointConfig(
            num_to_keep=1,
            checkpoint_score_attribute="loss",
            checkpoint_score_order="min",
        ),
    ),
    preprocessor=tokenizer,
)

# %%
result = trainer.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-05-09 02:01:43</td></tr>
# <tr><td>Running for: </td><td>00:16:28.79        </td></tr>
# <tr><td>Memory:      </td><td>11.8/14.7 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 0/4 CPUs, 0/4 GPUs, 0.0/7.35 GiB heap, 0.0/3.68 GiB objects
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name                    </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                    </th></tr>
# </thead>
# <tbody>
# <tr><td>HuggingFaceTrainer_24ef3_00000</td><td style="text-align: right;">           1</td><td>/home/rj2665/ray_results/HuggingFaceTrainer_2023-05-09_01-45-14/HuggingFaceTrainer_24ef3_00000_0_2023-05-09_01-45-15/error.txt</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                    </th><th>status  </th><th>loc             </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  loss</th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  epoch</th></tr>
# </thead>
# <tbody>
# <tr><td>HuggingFaceTrainer_24ef3_00000</td><td>ERROR   </td><td>10.158.0.3:12722</td><td style="text-align: right;">  1563</td><td style="text-align: right;">         971.779</td><td style="text-align: right;">0.3112</td><td style="text-align: right;">    1.27877e-08</td><td style="text-align: right;">1.99872</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2023-05-09 01:45:15,092	INFO wandb.py:314 -- Already logged into W&B.
# (_WandbLoggingActor pid=12725) wandb: Currently logged in as: rj2665 (hpml3). Use `wandb login --relogin` to force relogin
# (HuggingFaceTrainer pid=12722) 2023-05-09 01:45:24,146	INFO bulk_executor.py:39 -- Executing DAG InputDataBuffer[Input] -> TaskPoolMapOperator[BatchMapper] -> AllToAllOperator[randomize_block_order]
# (_WandbLoggingActor pid=12725) wandb: Tracking run with wandb version 0.15.2
# (_WandbLoggingActor pid=12725) wandb: Run data is saved locally in /home/rj2665/ray_results/HuggingFaceTrainer_2023-05-09_01-45-14/HuggingFaceTrainer_24ef3_00000_0_2023-05-09_01-45-15/wandb/run-20230509_014518-24ef3_00000
# (_WandbLoggingActor pid=12725) wandb: Run `wandb offline` to turn off syncing.
# (_WandbLoggingActor pid=12725) wandb: Syncing run HuggingFaceTrainer_24ef3_00000
# (_WandbLoggingActor pid=12725) wandb: ⭐️ View project at https://wandb.ai/hpml3/ray-roberta-finetune-imdb
# (_WandbLoggingActor pid=12725) wandb: 🚀 View run at https://wandb.ai/hpml3/ray-roberta-finetune-imdb/runs/24ef3_00000
# (HuggingFaceTrainer pid=12722) 2023-05-09 01:46:23,933	WARNING plan.py:524 -- Warning: The Ray cluster currently does not have any available CPUs. The Dataset job will hang unless more CPUs are freed up. A common reason is that cluster resources are used by Actors or Tune trials; see the following link for more details: https://docs.ray.io/en/master/data/dataset-internals.html#datasets-and-tune
# (HuggingFaceTrainer pid=12722) 2023-05-09 01:46:23,934	WARNING plan.py:524 -- Warning: The Ray cluster currently does not have any available CPUs. The Dataset job will hang unless more CPUs are freed up. A common reason is that cluster resources are used by Actors or Tune trials; see the following link for more details: https://docs.ray.io/en/master/data/dataset-internals.html#datasets-and-tune
# (HuggingFaceTrainer pid=12722) 2023-05-09 01:46:23,934	INFO bulk_executor.py:39 -- Executing DAG InputDataBuffer[Input] -> TaskPoolMapOperator[BatchMapper] -> AllToAllOperator[randomize_block_order]
# (RayTrainWorker pid=13732) 2023-05-09 01:47:21,868	INFO config.py:87 -- Setting up process group for: env:// [rank=0, world_size=2]
# (HuggingFaceTrainer pid=12722) /opt/conda/lib/python3.7/site-packages/ray/data/_internal/bulk_dataset_iterator.py:109: UserWarning: session.get_dataset_shard returns a ray.data.DatasetIterator instead of a Dataset as of Ray v2.3. Use iter_torch_batches(), to_tf(), or iter_batches() to iterate over one epoch. See https://docs.ray.io/en/latest/data/api/dataset_iterator.html for full DatasetIterator docs.
# (HuggingFaceTrainer pid=12722)   "session.get_dataset_shard returns a ray.data.DatasetIterator "
# (RayTrainWorker pid=13732) /opt/conda/lib/python3.7/site-packages/ray/data/_internal/bulk_dataset_iterator.py:109: UserWarning: session.get_dataset_shard returns a ray.data.DatasetIterator instead of a Dataset as of Ray v2.3. Use iter_torch_batches(), to_tf(), or iter_batches() to iterate over one epoch. See https://docs.ray.io/en/latest/data/api/dataset_iterator.html for full DatasetIterator docs.
# (RayTrainWorker pid=13732)   "session.get_dataset_shard returns a ray.data.DatasetIterator "
# (RayTrainWorker pid=13733) /opt/conda/lib/python3.7/site-packages/ray/data/_internal/bulk_dataset_iterator.py:109: UserWarning: session.get_dataset_shard returns a ray.data.DatasetIterator instead of a Dataset as of Ray v2.3. Use iter_torch_batches(), to_tf(), or iter_batches() to iterate over one epoch. See https://docs.ray.io/en/latest/data/api/dataset_iterator.html for full DatasetIterator docs.
# (RayTrainWorker pid=13733)   "session.get_dataset_shard returns a ray.data.DatasetIterator "
# (RayTrainWorker pid=13733) Is CUDA available: True
# (RayTrainWorker pid=13732) Is CUDA available: True
# (RayTrainWorker pid=13732) Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.dense.weight', 'lm_head.bias', 'lm_head.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight']
# (RayTrainWorker pid=13732) - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (RayTrainWorker pid=13732) - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (RayTrainWorker pid=13732) Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.bias']
# (RayTrainWorker pid=13732) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (RayTrainWorker pid=13733) Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'roberta.pooler.dense.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.weight']
# (RayTrainWorker pid=13733) - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (RayTrainWorker pid=13733) - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (RayTrainWorker pid=13733) Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.dense.bias']
# (RayTrainWorker pid=13733) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (RayTrainWorker pid=13733) Starting training
# (RayTrainWorker pid=13732) Starting training
# (RayTrainWorker pid=13733) Installed CUDA version 11.3 does not match the version torch was compiled with 11.7 but since the APIs are compatible, accepting this combination
# (RayTrainWorker pid=13732) Installed CUDA version 11.3 does not match the version torch was compiled with 11.7 but since the APIs are compatible, accepting this combination
# (RayTrainWorker pid=13732) Using /home/rj2665/.cache/torch_extensions/py37_cu117 as PyTorch extensions root...
# (RayTrainWorker pid=13733) Using /home/rj2665/.cache/torch_extensions/py37_cu117 as PyTorch extensions root...
# (RayTrainWorker pid=13732) Detected CUDA files, patching ldflags
# (RayTrainWorker pid=13732) Emitting ninja build file /home/rj2665/.cache/torch_extensions/py37_cu117/cpu_adam/build.ninja...
# (RayTrainWorker pid=13732) Building extension module cpu_adam...
# (RayTrainWorker pid=13732) Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# (RayTrainWorker pid=13733) Installed CUDA version 11.3 does not match the version torch was compiled with 11.7 but since the APIs are compatible, accepting this combination
# (RayTrainWorker pid=13732) Installed CUDA version 11.3 does not match the version torch was compiled with 11.7 but since the APIs are compatible, accepting this combination
# (RayTrainWorker pid=13732) Loading extension module cpu_adam...
# (RayTrainWorker pid=13733) Loading extension module cpu_adam...
# (RayTrainWorker pid=13732) ninja: no work to do.
# (RayTrainWorker pid=13732) Time to load cpu_adam op: 2.625136137008667 seconds
# (RayTrainWorker pid=13733) Time to load cpu_adam op: 2.715188503265381 seconds
# (RayTrainWorker pid=13733) Using /home/rj2665/.cache/torch_extensions/py37_cu117 as PyTorch extensions root...
# (RayTrainWorker pid=13732) Using /home/rj2665/.cache/torch_extensions/py37_cu117 as PyTorch extensions root...
# (RayTrainWorker pid=13733) ninja: no work to do.
# (RayTrainWorker pid=13733) Time to load utils op: 0.23445630073547363 seconds
# (RayTrainWorker pid=13732) Time to load utils op: 0.2026958465576172 seconds
# (RayTrainWorker pid=13733) Emitting ninja build file /home/rj2665/.cache/torch_extensions/py37_cu117/utils/build.ninja...
# (RayTrainWorker pid=13733) Building extension module utils...
# (RayTrainWorker pid=13733) Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# (RayTrainWorker pid=13733) Loading extension module utils...
# (RayTrainWorker pid=13732) Loading extension module utils...
# (RayTrainWorker pid=13732) Parameter Offload: Total persistent parameters: 64514 in 66 params
# (RayTrainWorker pid=13733) Time to load utils op: 0.0005412101745605469 seconds
# (RayTrainWorker pid=13733) Using /home/rj2665/.cache/torch_extensions/py37_cu117 as PyTorch extensions root...
# (RayTrainWorker pid=13733) No modifications detected for re-loaded extension module utils, skipping build step...
# (RayTrainWorker pid=13733) Loading extension module utils...
# (RayTrainWorker pid=13732) Using /home/rj2665/.cache/torch_extensions/py37_cu117 as PyTorch extensions root...
# (RayTrainWorker pid=13732) No modifications detected for re-loaded extension module utils, skipping build step...
# (RayTrainWorker pid=13732) Loading extension module utils...
# (RayTrainWorker pid=13732) Time to load utils op: 0.0003960132598876953 seconds
# (RayTrainWorker pid=13732) {'loss': 0.7249, 'learning_rate': 1.9987212276214835e-05, 'epoch': 0.0}
# (RayTrainWorker pid=13732) {'loss': 0.709, 'learning_rate': 1.997442455242967e-05, 'epoch': 0.0}
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                    </th><th style="text-align: right;">  _time_this_iter_s</th><th style="text-align: right;">  _timestamp</th><th style="text-align: right;">  _training_iteration</th><th>date               </th><th>done  </th><th>episodes_total  </th><th style="text-align: right;">  epoch</th><th>experiment_id                   </th><th style="text-align: right;">  experiment_tag</th><th>hostname  </th><th style="text-align: right;">  iterations_since_restore</th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  loss</th><th>node_ip   </th><th style="text-align: right;">  pid</th><th style="text-align: right;">  step</th><th style="text-align: right;">  time_since_restore</th><th style="text-align: right;">  time_this_iter_s</th><th style="text-align: right;">  time_total_s</th><th style="text-align: right;">  timestamp</th><th style="text-align: right;">  timesteps_since_restore</th><th>timesteps_total  </th><th style="text-align: right;">  training_iteration</th><th>trial_id   </th><th style="text-align: right;">  warmup_time</th></tr>
# </thead>
# <tbody>
# <tr><td>HuggingFaceTrainer_24ef3_00000</td><td style="text-align: right;">           0.530241</td><td style="text-align: right;">  1683597695</td><td style="text-align: right;">                 1563</td><td>2023-05-09_02-01-35</td><td>False </td><td>                </td><td style="text-align: right;">1.99872</td><td>b22c34d8cad341c48ff258428f7beab3</td><td style="text-align: right;">               0</td><td>instance-7</td><td style="text-align: right;">                      1563</td><td style="text-align: right;">    1.27877e-08</td><td style="text-align: right;">0.3112</td><td>10.158.0.3</td><td style="text-align: right;">12722</td><td style="text-align: right;">  1563</td><td style="text-align: right;">             971.779</td><td style="text-align: right;">           0.53044</td><td style="text-align: right;">       971.779</td><td style="text-align: right;"> 1683597695</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                1563</td><td>24ef3_00000</td><td style="text-align: right;">     0.010596</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# 2023-05-09 01:47:46,370	WARNING util.py:244 -- The `callbacks.on_trial_result` operation took 1.352 s, which may be a performance bottleneck.
# 2023-05-09 01:47:46,372	WARNING util.py:244 -- The `process_trial_result` operation took 1.355 s, which may be a performance bottleneck.
# 2023-05-09 01:47:46,373	WARNING util.py:244 -- Processing trial results took 1.356 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2023-05-09 01:47:46,374	WARNING util.py:244 -- The `process_trial_result` operation took 1.357 s, which may be a performance bottleneck.
# (RayTrainWorker pid=13732) {'loss': 0.7117, 'learning_rate': 1.9961636828644503e-05, 'epoch': 0.0}
# (RayTrainWorker pid=13732) {'loss': 0.6987, 'learning_rate': 1.9948849104859337e-05, 'epoch': 0.01}
# (RayTrainWorker pid=13732) {'loss': 0.7009, 'learning_rate': 1.993606138107417e-05, 'epoch': 0.01}
# (RayTrainWorker pid=13732) {'loss': 0.6948, 'learning_rate': 1.9923273657289004e-05, 'epoch': 0.01}
# (RayTrainWorker pid=13732) {'loss': 0.6909, 'learning_rate': 1.9910485933503838e-05, 'epoch': 0.01}
# (RayTrainWorker pid=13732) {'loss': 0.6907, 'learning_rate': 1.9897698209718672e-05, 'epoch': 0.01}
# (RayTrainWorker pid=13732) {'loss': 0.6914, 'learning_rate': 1.9884910485933505e-05, 'epoch': 0.01}
# (RayTrainWorker pid=13732) {'loss': 0.6843, 'learning_rate': 1.987212276214834e-05, 'epoch': 0.01}
# (RayTrainWorker pid=13732) {'loss': 0.6907, 'learning_rate': 1.9859335038363173e-05, 'epoch': 0.01}
# (RayTrainWorker pid=13732) {'loss': 0.7061, 'learning_rate': 1.9846547314578007e-05, 'epoch': 0.02}
# (RayTrainWorker pid=13732) {'loss': 0.696, 'learning_rate': 1.983375959079284e-05, 'epoch': 0.02}
# (RayTrainWorker pid=13732) {'loss': 0.6838, 'learning_rate': 1.9820971867007674e-05, 'epoch': 0.02}
# (RayTrainWorker pid=13732) {'loss': 0.6907, 'learning_rate': 1.9808184143222508e-05, 'epoch': 0.02}
# (RayTrainWorker pid=13732) {'loss': 0.689, 'learning_rate': 1.9795396419437342e-05, 'epoch': 0.02}
# (RayTrainWorker pid=13732) {'loss': 0
 'epoch': 1.99}
# (RayTrainWorker pid=13732) {'loss': 0.0356, 'learning_rate': 1.1508951406649618e-07, 'epoch': 1.99}
# (RayTrainWorker pid=13732) {'loss': 0.2856, 'learning_rate': 1.0230179028132994e-07, 'epoch': 1.99}
# (RayTrainWorker pid=13732) {'loss': 0.0878, 'learning_rate': 8.951406649616369e-08, 'epoch': 1.99}
# (RayTrainWorker pid=13732) {'loss': 0.114, 'learning_rate': 7.672634271099745e-08, 'epoch': 1.99}
# (RayTrainWorker pid=13732) {'loss': 0.157, 'learning_rate': 6.393861892583121e-08, 'epoch': 1.99}
# (RayTrainWorker pid=13732) {'loss': 0.0979, 'learning_rate': 5.115089514066497e-08, 'epoch': 1.99}
# (RayTrainWorker pid=13732) {'loss': 0.1691, 'learning_rate': 3.8363171355498724e-08, 'epoch': 2.0}
# (RayTrainWorker pid=13732) {'loss': 0.0838, 'learning_rate': 2.5575447570332485e-08, 'epoch': 2.0}
# (RayTrainWorker pid=13732) {'loss': 0.3112, 'learning_rate': 1.2787723785166243e-08, 'epoch': 2.0}
# (RayTrainWorker pid=13732) {'loss': 0.0468, 'learning_rate': 0.0, 'epoch': 2.0}
# (RayTrainWorker pid=13732) /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py:1433: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
# (RayTrainWorker pid=13732)   "Positional args are being deprecated, use kwargs instead. Refer to "
# (RayTrainWorker pid=13733) /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py:1433: UserWarning: Positional args are being deprecated, use kwargs instead. Refer to https://pytorch.org/docs/master/generated/torch.nn.Module.html#torch.nn.Module.state_dict for details.
# (RayTrainWorker pid=13733)   "Positional args are being deprecated, use kwargs instead. Refer to "
# (RayTrainWorker pid=13732) {'train_runtime': 835.0049, 'train_samples_per_second': 29.94, 'train_steps_per_second': 1.873, 'train_loss': 0.20461657528987015, 'epoch': 2.0}
# 2023-05-09 02:01:39,259	ERROR trial_runner.py:1062 -- Trial HuggingFaceTrainer_24ef3_00000: Error processing event.
# ray.exceptions.RayTaskError(PermissionError): ray::_Inner.train() (pid=12722, ip=10.158.0.3, repr=HuggingFaceTrainer)
#   File "/opt/conda/lib/python3.7/site-packages/ray/tune/trainable/trainable.py", line 368, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/conda/lib/python3.7/site-packages/ray/tune/trainable/function_trainable.py", line 340, in entrypoint
#     self._status_reporter.get_checkpoint(),
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/base_trainer.py", line 505, in _trainable_func
#     super()._trainable_func(self._merged_config, reporter, checkpoint_dir)
#   File "/opt/conda/lib/python3.7/site-packages/ray/tune/trainable/function_trainable.py", line 654, in _trainable_func
#     output = fn()
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/base_trainer.py", line 415, in train_func
#     trainer.training_loop()
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/data_parallel_trainer.py", line 395, in training_loop
#     self._report(training_iterator)
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/data_parallel_trainer.py", line 342, in _report
#     for results in training_iterator:
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/trainer.py", line 134, in __next__
#     next_results = self._run_with_error_handling(self._fetch_next_result)
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/trainer.py", line 97, in _run_with_error_handling
#     return func()
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/trainer.py", line 178, in _fetch_next_result
#     results, decode_checkpoint_fn=self._backend._decode_data
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/_internal/checkpoint.py", line 138, in _process_checkpoint
#     self.register_checkpoint(checkpoint=tracked_checkpoint)
#   File "/opt/conda/lib/python3.7/site-packages/ray/air/_internal/checkpoint_manager.py", line 322, in register_checkpoint
#     self._process_persistent_checkpoint(persisted_checkpoint)
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/data_parallel_trainer.py", line 51, in _process_persistent_checkpoint
#     checkpoint=checkpoint
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/_internal/checkpoint.py", line 235, in _process_persistent_checkpoint
#     checkpoint.commit(path)
#   File "/opt/conda/lib/python3.7/site-packages/ray/air/_internal/checkpoint_manager.py", line 118, in commit
#     self.dir_or_data = self.dir_or_data._move_directory(str(path))
#   File "/opt/conda/lib/python3.7/site-packages/ray/air/checkpoint.py", line 578, in _move_directory
#     self._local_path = self._to_directory_safe(path, move_instead_of_copy=True)
#   File "/opt/conda/lib/python3.7/site-packages/ray/air/checkpoint.py", line 552, in _to_directory_safe
#     with TempFileLock(f"{path}.lock", timeout=0):
#   File "/opt/conda/lib/python3.7/site-packages/ray/air/_internal/filelock.py", line 27, in __enter__
#     self._lock.acquire()
#   File "/home/rj2665/.local/lib/python3.7/site-packages/filelock/_api.py", line 217, in acquire
#     self._acquire()
#   File "/home/rj2665/.local/lib/python3.7/site-packages/filelock/_unix.py", line 36, in _acquire
#     fd = os.open(self.lock_file, open_flags, self._context.mode)
# PermissionError: [Errno 13] Permission denied: '/var/tmp/_ray_lockfiles/093f4a1c2ca67cc61c2778194a79a9fd.lock'
# (_WandbLoggingActor pid=12725) wandb: Waiting for W&B process to finish... (success).
# (_WandbLoggingActor pid=12725) wandb: - 0.002 MB of 0.018 MB uploaded (0.000 MB deduped)
# (_WandbLoggingActor pid=12725) wandb: \ 0.002 MB of 0.018 MB uploaded (0.000 MB deduped)
# (_WandbLoggingActor pid=12725) wandb:
# (_WandbLoggingActor pid=12725) wandb: Run history:
# (_WandbLoggingActor pid=12725) wandb:                    epoch ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# (_WandbLoggingActor pid=12725) wandb: iterations_since_restore ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# (_WandbLoggingActor pid=12725) wandb:            learning_rate ███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# (_WandbLoggingActor pid=12725) wandb:                     loss █▄▃▂▄▅▅▂▃▅▃▂▂▂▃▂▄▄▅▆▃▁▁▁▂▃▂▃█▂▁▁▃▃▂▆▃▁▂▁
# (_WandbLoggingActor pid=12725) wandb:                     step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# (_WandbLoggingActor pid=12725) wandb:       time_since_restore ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# (_WandbLoggingActor pid=12725) wandb:         time_this_iter_s ▆▂▄▃▂▃▁▂▄▄▁▂▁▄▄▂▁▂▅▂▄▁▃▁▃▃▇▁▂▂▂▂▁▂▃█▃▃█▂
# (_WandbLoggingActor pid=12725) wandb:             time_total_s ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# (_WandbLoggingActor pid=12725) wandb:                timestamp ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# (_WandbLoggingActor pid=12725) wandb:  timesteps_since_restore ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# (_WandbLoggingActor pid=12725) wandb:       training_iteration ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# (_WandbLoggingActor pid=12725) wandb:              warmup_time ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# (_WandbLoggingActor pid=12725) wandb:
# (_WandbLoggingActor pid=12725) wandb: Run summary:
# (_WandbLoggingActor pid=12725) wandb:                    epoch 1.99872
# (_WandbLoggingActor pid=12725) wandb: iterations_since_restore 1563
# (_WandbLoggingActor pid=12725) wandb:            learning_rate 0.0
# (_WandbLoggingActor pid=12725) wandb:                     loss 0.3112
# (_WandbLoggingActor pid=12725) wandb:                     step 1563
# (_WandbLoggingActor pid=12725) wandb:       time_since_restore 971.77904
# (_WandbLoggingActor pid=12725) wandb:         time_this_iter_s 0.53044
# (_WandbLoggingActor pid=12725) wandb:             time_total_s 971.77904
# (_WandbLoggingActor pid=12725) wandb:                timestamp 1683597695
# (_WandbLoggingActor pid=12725) wandb:  timesteps_since_restore 0
# (_WandbLoggingActor pid=12725) wandb:       training_iteration 1563
# (_WandbLoggingActor pid=12725) wandb:              warmup_time 0.0106
# (_WandbLoggingActor pid=12725) wandb:
# (_WandbLoggingActor pid=12725) wandb: 🚀 View run HuggingFaceTrainer_24ef3_00000 at: https://wandb.ai/hpml3/ray-roberta-finetune-imdb/runs/24ef3_00000
# (_WandbLoggingActor pid=12725) wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# (_WandbLoggingActor pid=12725) wandb: Find logs at: ./wandb/run-20230509_014518-24ef3_00000/logs
# 2023-05-09 02:01:43,898	ERROR tune.py:794 -- Trials did not complete: [HuggingFaceTrainer_24ef3_00000]
# 2023-05-09 02:01:43,900	INFO tune.py:799 -- Total run time: 988.91 seconds (988.78 seconds for the tuning loop).
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 result = trainer.fit()                                                                       │
# │   2                                                                                              │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/ray/train/base_trainer.py:368 in fit                      │
# │                                                                                                  │
# │   365 │   │   try:                                                                               │
# │   366 │   │   │   result = result_grid[0]                                                        │
# │   367 │   │   │   if result.error:                                                               │
# │ ❱ 368 │   │   │   │   raise result.error                                                         │
# │   369 │   │   except TuneError as e:                                                             │
# │   370 │   │   │   raise TrainingFailedError from e                                               │
# │   371 │   │   return result                                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# RayTaskError(PermissionError): [36mray::_Inner.train()[39m (pid=12722, ip=10.158.0.3, repr=HuggingFaceTrainer)
#   File "/opt/conda/lib/python3.7/site-packages/ray/tune/trainable/trainable.py", line 368, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/conda/lib/python3.7/site-packages/ray/tune/trainable/function_trainable.py", line 340, in entrypoint
#     self._status_reporter.get_checkpoint(),
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/base_trainer.py", line 505, in _trainable_func
#     super()._trainable_func(self._merged_config, reporter, checkpoint_dir)
#   File "/opt/conda/lib/python3.7/site-packages/ray/tune/trainable/function_trainable.py", line 654, in
# _trainable_func
#     output = fn()
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/base_trainer.py", line 415, in train_func
#     trainer.training_loop()
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/data_parallel_trainer.py", line 395, in training_loop
#     self._report(training_iterator)
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/data_parallel_trainer.py", line 342, in _report
#     for results in training_iterator:
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/trainer.py", line 134, in __next__
#     next_results = self._run_with_error_handling(self._fetch_next_result)
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/trainer.py", line 97, in _run_with_error_handling
#     return func()
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/trainer.py", line 178, in _fetch_next_result
#     results, decode_checkpoint_fn=self._backend._decode_data
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/_internal/checkpoint.py", line 138, in _process_checkpoint
#     self.register_checkpoint(checkpoint=tracked_checkpoint)
#   File "/opt/conda/lib/python3.7/site-packages/ray/air/_internal/checkpoint_manager.py", line 322, in
# register_checkpoint
#     self._process_persistent_checkpoint(persisted_checkpoint)
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/data_parallel_trainer.py", line 51, in
# _process_persistent_checkpoint
#     checkpoint=checkpoint
#   File "/opt/conda/lib/python3.7/site-packages/ray/train/_internal/checkpoint.py", line 235, in
# _process_persistent_checkpoint
#     checkpoint.commit(path)
#   File "/opt/conda/lib/python3.7/site-packages/ray/air/_internal/checkpoint_manager.py", line 118, in commit
#     self.dir_or_data = self.dir_or_data._move_directory(str(path))
#   File "/opt/conda/lib/python3.7/site-packages/ray/air/checkpoint.py", line 578, in _move_directory
#     self._local_path = self._to_directory_safe(path, move_instead_of_copy=True)
#   File "/opt/conda/lib/python3.7/site-packages/ray/air/checkpoint.py", line 552, in _to_directory_safe
#     with TempFileLock(f"{path}.lock", timeout=0):
#   File "/opt/conda/lib/python3.7/site-packages/ray/air/_internal/filelock.py", line 27, in __enter__
#     self._lock.acquire()
#   File "/home/rj2665/.local/lib/python3.7/site-packages/filelock/_api.py", line 217, in acquire
#     self._acquire()
#   File "/home/rj2665/.local/lib/python3.7/site-packages/filelock/_unix.py", line 36, in _acquire
#     fd = os.open(self.lock_file, open_flags, self._context.mode)
# PermissionError: [Errno 13] Permission denied: '/var/tmp/_ray_lockfiles/093f4a1c2ca67cc61c2778194a79a9fd.lock'
